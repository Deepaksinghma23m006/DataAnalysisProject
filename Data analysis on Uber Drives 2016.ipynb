# %%
mylist=[43,43,45,75,34,34]
#mylist[1:3]
mylist.append(8)
mylist
# Out:
# [43, 43, 45, 75, 34, 34, 8]

# %% [markdown]
# this is tile

# %%
# !pip install pandas

# %%
from pandas import read_csv

# %%
import pandas as pd
df=pd.read_csv("Uber Drives 2016.csv")

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 0          Fort Pierce      5.1   Meal/Entertain
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes   #tells types of columns #object means string
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %% [markdown]
# here columns are called series

# %%
df.head(n=11)      #gives sample
# Out:
#         START_DATE*        END_DATE* CATEGORY*           START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business      Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business      Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business      Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business      Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business      Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business  West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business  West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business             Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business             Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business          Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business         New York
#
#               STOP*  MILES*         PURPOSE*
# 0       Fort Pierce     5.1   Meal/Entertain
# 1       Fort Pierce     5.0              NaN
# 2       Fort Pierce     4.8  Errand/Supplies
# ...

# %%
df.shape  # no. of rows and columns
# Out:
# (1156, 7)

# %%
df.tail(n=1000)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 156    2/24/2016 14:30   2/24/2016 14:35  Business       Whitebridge
# 157    2/24/2016 15:19   2/24/2016 15:25  Business           Preston
# 158    2/25/2016 16:27   2/25/2016 16:35  Business       Whitebridge
# 159    2/25/2016 16:47   2/25/2016 17:02  Business    Heritage Pines
# 160    2/25/2016 17:16   2/25/2016 17:36  Business       Whitebridge
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# 156            Preston      1.5              NaN
# ...

# %% [markdown]
# ###CHANGING DATA TYPES ( CHANGE TYPE OF DATE )

# %%
temp=pd.DataFrame({"A":["1","2","3"],"B":[11,12,13],"C":["12-06-2012","13-06-2015","15-06-2018"]})

# %%
temp
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  13-06-2015
# 2  3  13  15-06-2018

# %%
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %% [markdown]
# #Now we well convert c object to date type

# %%
pd.to_datetime("2201-03-01")
# Out:
# Timestamp('2201-03-01 00:00:00')

# %%
temp["C"]=pd.to_datetime(temp["C"])
temp
# Out:
#    A   B          C
# 0  1  11 2012-12-06
# 1  2  12 2015-06-13
# 2  3  13 2018-06-15

# %%
temp.dtypes    #here we done it
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
pd.to_datetime(["2016-sep-11","abc"],errors="coerce")
# Out:
# DatetimeIndex(['2016-09-11', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %% [markdown]
# # For convert A to numeric

# %%
temp["A"]=pd.to_numeric(temp["A"])   # noted
temp
# Out:
#    A   B          C
# 0  1  11 2012-12-06
# 1  2  12 2015-06-13
# 2  3  13 2018-06-15

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %% [markdown]
# For covert A to string

# %%
temp["A"]=temp["A"].astype(str)
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %%
pd.to_datetime(df["START_DATE*"],format='%m'/%d/%Y%H:%M)        # dont know
# Out:
#   Cell In[8], line 1
#     pd.to_datetime(df["START_DATE*"],format='%m'/%d/%Y%H:%M)
#                                                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Dataset summarization method

# %%
df.describe(include='all')
# Out:
#             START_DATE*        END_DATE* CATEGORY* START* STOP*        MILES*  \
# count              1156             1155      1155   1155  1155   1156.000000
# unique             1155             1154         2    177   188           NaN
# top     6/28/2016 23:34  6/28/2016 23:59  Business   Cary  Cary           NaN
# freq                  2                2      1078    201   203           NaN
# mean                NaN              NaN       NaN    NaN   NaN     21.115398
# std                 NaN              NaN       NaN    NaN   NaN    359.299007
# min                 NaN              NaN       NaN    NaN   NaN      0.500000
# 25%                 NaN              NaN       NaN    NaN   NaN      2.900000
# 50%                 NaN              NaN       NaN    NaN   NaN      6.000000
# 75%                 NaN              NaN       NaN    NaN   NaN     10.400000
# max                 NaN              NaN       NaN    NaN   NaN  12204.700000
#
#        PURPOSE*
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1156 entries, 0 to 1155
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   START_DATE*  1156 non-null   object
#  1   END_DATE*    1155 non-null   object
#  2   CATEGORY*    1155 non-null   object
#  3   START*       1155 non-null   object
#  4   STOP*        1155 non-null   object
#  5   MILES*       1156 non-null   float64
#  6   PURPOSE*     653 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 63.3+ KB

# %%
df["START*"].value_counts()    #gives no. of trips which 'start' location wise
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
#                    ...
# Florence              1
# Ridgeland             1
# Daytona Beach         1
# Sky Lake              1
# Gampaha               1
# Name: START*, Length: 177, dtype: int64

# %% [markdown]
# # common data mannipulation tasks
#
# selecting/indexing ; filtering;sorting; mutating/conditionally adding column; group by/summarize

# %% [markdown]
# # 1. Selecting/indexing  (iloc-by row&column ; loc-by name)

# %%
df.iloc[0:5,0:4]   #(0:5 is row & 0:4 is column)
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce

# %%
df.iloc[0:5,[0,3]]    # for only column 0 and 3
# Out:
#       START_DATE*       START*
# 0  1/1/2016 21:11  Fort Pierce
# 1   1/2/2016 1:25  Fort Pierce
# 2  1/2/2016 20:25  Fort Pierce
# 3  1/5/2016 17:31  Fort Pierce
# 4  1/6/2016 14:42  Fort Pierce

# %%
df.iloc[0:5]  # for fixed rows and all columns
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.iloc[:,0:4]  #for all rows and fixed columns
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
# [1156 rows x 4 columns]

# %%
raghu=df.iloc[:,:-1]     #all rows and columns excpt last column
raghu
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*
# 0          Fort Pierce      5.1
# 1          Fort Pierce      5.0
# 2          Fort Pierce      4.8
# ...

# %%
df.shape
# Out:
# (1156, 7)

# %%
raghu.shape
# Out:
# (1156, 6)

# %% [markdown]
#  By label based indexing (i.e by name or loc)

# %%
df.loc[:,["START*","STOP*"]]       # all rows & start,stop columns
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1151           Kar?chi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
# 1155               NaN               NaN
#
# [1156 rows x 2 columns]

# %%
df[["START*","STOP*"]]           # OR we can use this also
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1151           Kar?chi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
# 1155               NaN               NaN
#
# [1156 rows x 2 columns]

# %% [markdown]
# difference between series and dataframe  (b/w abc & defg)

# %%
abc=df.loc[:,"START*"]
abc
# Out:
# 0            Fort Pierce
# 1            Fort Pierce
# 2            Fort Pierce
# 3            Fort Pierce
# 4            Fort Pierce
#               ...
# 1151             Kar?chi
# 1152    Unknown Location
# 1153          Katunayake
# 1154             Gampaha
# 1155                 NaN
# Name: START*, Length: 1156, dtype: object

# %%
type(abc)
# Out:
# pandas.core.series.Series

# %%
defg=df.loc[:,["START*"]]
defg
# Out:
#                 START*
# 0          Fort Pierce
# 1          Fort Pierce
# 2          Fort Pierce
# 3          Fort Pierce
# 4          Fort Pierce
# ...                ...
# 1151           Kar?chi
# 1152  Unknown Location
# 1153        Katunayake
# 1154           Gampaha
# 1155               NaN
#
# [1156 rows x 1 columns]

# %%
type(defg)
# Out:
# pandas.core.frame.DataFrame

# %%
re=df.loc[:,("START*","STOP*")]       #we can use tuple() also in place of list[] but we prefer list because its mutable
re
# Out:
#                 START*             STOP*
# 0          Fort Pierce       Fort Pierce
# 1          Fort Pierce       Fort Pierce
# 2          Fort Pierce       Fort Pierce
# 3          Fort Pierce       Fort Pierce
# 4          Fort Pierce   West Palm Beach
# ...                ...               ...
# 1151           Kar?chi  Unknown Location
# 1152  Unknown Location  Unknown Location
# 1153        Katunayake           Gampaha
# 1154           Gampaha         Ilukwatta
# 1155               NaN               NaN
#
# [1156 rows x 2 columns]

# %% [markdown]
# # filtering

# %%
df["MILES*"]>10
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1151    False
# 1152     True
# 1153    False
# 1154     True
# 1155     True
# Name: MILES*, Length: 1156, dtype: bool

# %%
df2=df.loc[df["MILES*"]>10]  # shows miles greater than 10
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
df22=df.loc[df["MILES*"]>20,["MILES*","START_DATE*"]] # shows only start date&  miles column which greter than 20
df22
# Out:
#        MILES*       START_DATE*
# 4        63.7    1/6/2016 14:42
# 25       21.9   1/14/2016 16:29
# 36       40.2   1/20/2016 13:25
# 62       23.3    2/1/2016 12:10
# 108      43.7    2/16/2016 3:21
# ...       ...               ...
# 1088    103.0  12/21/2016 20:56
# 1089     32.3  12/22/2016 15:40
# 1092     23.2  12/22/2016 17:56
# 1154     48.2  12/31/2016 22:08
# 1155  12204.7            Totals
#
# [84 rows x 2 columns]

# %% [markdown]
# Q: find all rides from newyork

# %%
df.loc[df["START*"]=="New York", ["MILES*"]]  #Answer
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %% [markdown]
# Q: find out all rides to carry and new york

# %%
myrides=df.loc[df["START*"].isin(["Cary","New York"])]   #answer
myrides
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %% [markdown]
# Q:find trips with distance >10 miles and originating from cary&newyork

# %%
ride=df.loc[(df["MILES*"]>10)&(df["START*"].isin(["Cary","New York"]))]
ride
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# 34     1/20/2016 10:36   1/20/2016 11:11  Business      Cary        Raleigh
# 46     1/27/2016 10:19   1/27/2016 10:48  Business      Cary        Raleigh
# ...                ...               ...       ...       ...            ...
# 990   11/22/2016 15:51  11/22/2016 16:43  Business      Cary           Cary
# 997   11/25/2016 11:47  11/25/2016 12:04  Business      Cary         Durham
# 1035   12/9/2016 22:03   12/9/2016 22:57  Business      Cary           Cary
# 1036  12/10/2016 12:43  12/10/2016 13:16  Business      Cary  Fuquay-Varina
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
#ride1=df.loc[(df["MILES*"]>10)&(df["START*"]==("Cary","New York")]
#ride1

# %%
ride.reset_index(inplace=True,drop=True)  # for indexing # drop means to remove old index
ride    #inplace = true means chage actual data (or rd=ride.reset_index(inplace=True,drop=True and run rd)
# Out:
#          START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 0    1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 1    1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 2    1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# 3    1/20/2016 10:36   1/20/2016 11:11  Business      Cary        Raleigh
# 4    1/27/2016 10:19   1/27/2016 10:48  Business      Cary        Raleigh
# ..               ...               ...       ...       ...            ...
# 57  11/22/2016 15:51  11/22/2016 16:43  Business      Cary           Cary
# 58  11/25/2016 11:47  11/25/2016 12:04  Business      Cary         Durham
# 59   12/9/2016 22:03   12/9/2016 22:57  Business      Cary           Cary
# 60  12/10/2016 12:43  12/10/2016 13:16  Business      Cary  Fuquay-Varina
# 61  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#     MILES*        PURPOSE*
# 0     10.8         Meeting
# ...

# %% [markdown]
# # Sorting

# %%
df.sort_values(by="MILES*",ascending=False).head(5)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
#
#                  STOP*   MILES*        PURPOSE*
# 1155               NaN  12204.7             NaN
# 269       Jacksonville    310.3  Customer Visit
# 270          Kissimmee    201.0         Meeting
# 881             Mebane    195.9             NaN
# 776   Unknown Location    195.6             NaN

# %%
df.sort_values(by=["START*","MILES*"],ascending=[True,False]).head(20)  #means with first letter a show all decresing miles then with b
# Out:
#            START_DATE*         END_DATE* CATEGORY*  START*          STOP*  \
# 906    11/4/2016 21:04   11/4/2016 21:20  Business   Agnew           Cory
# 911    11/6/2016 10:50   11/6/2016 11:04  Business   Agnew    Renaissance
# 908     11/5/2016 8:34    11/5/2016 8:43  Business   Agnew    Renaissance
# 910    11/5/2016 19:20   11/5/2016 19:28  Business   Agnew          Agnew
# 879   10/30/2016 12:58  10/30/2016 13:18  Business  Almond    Bryson City
# 1001  11/26/2016 17:36  11/26/2016 17:56  Business    Apex  Holly Springs
# 1033   12/9/2016 13:15   12/9/2016 13:43  Business    Apex           Cary
# 410     6/6/2016 21:08    6/6/2016 21:37  Business    Apex           Cary
# 647    8/10/2016 19:47   8/10/2016 20:02  Business    Apex           Cary
# 60     1/30/2016 18:09   1/30/2016 18:24  Business    Apex           Cary
# 80      2/7/2016 18:03    2/7/2016 18:17  Business    Apex           Cary
# 173    2/29/2016 12:36   2/29/2016 12:48  Business    Apex           Cary
# ...

# %%
import numpy as np

# %%
df["miles_cat"]=np.where(df["MILES*"]>5,"long trip","short trip")   #to add a column by conditinally statement
#if miles >5 print long else print short

# %%
df.head(5)
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*   miles_cat
# 0     5.1   Meal/Entertain   long trip
# 1     5.0              NaN  short trip
# 2     4.8  Errand/Supplies  short trip
# 3     4.7          Meeting  short trip
# 4    63.7   Customer Visit   long trip

# %%
df["my_year"]=np.array(2000) # to add column with only one entry
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   miles_cat  my_year
# ...

# %%
# Q >10 - long trip ; <5-shorttrip ; 5-10-medium trip


df["ass"]=np.where(df["MILES*"]<5,"short trip",np.where(df["MILES*"]>10,"long trip","medium trip")) # used np.where again
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*   miles_cat  my_year  \
# ...
